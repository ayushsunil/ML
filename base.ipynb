# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushsunil/ML/blob/main/base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=1.5
type(A)
# Out:
# float

# %%
A=int(input("enter first number"))
b=int(input("enter sec number"))
c=A+b
print("the sum  "+str(c))
# Out:
# enter first number12
# enter sec number23
# the sum  35

# %%
a=int(input("enter the mark"))
if a>50:
  if a%2==0:
    print("even number")
  else:
    print("odd number")
else:
    print("number less than 50")
# Out:
# enter the mark12
# number less than 50

# %%
list=['ayn','are','pari','myr','andi']
for i in list:
  print(i)
# Out:
# ayn
# are
# pari
# myr
# andi

# %%
for i in range(100,0,-2):
  print(i)
# Out:
# 100
# 98
# 96
# 94
# 92
# 90
# 88
# 86
# 84
# 82
# 80
# 78
# 76
# 74
# 72
# 70
# 68
# 66
# 64
# 62
# 60
# 58
# 56
# 54
# 52
# 50
# 48
# 46
# 44
# 42
# 40
# 38
# 36
# 34
# 32
# 30
# 28
# 26
# 24
# 22
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4
# 2

# %%
time=input("enter the time at which the boat is required for : ")
distance=int(input("the amount of travel distance"))
total_cost=(5+distance)
if time=="morning":
  print(total_cost*1.2)
elif time=="afternoon":
    print(total_cost*1.1)
elif time=="evening":
    print(total_cost*1.5)
elif time=="night":
    print(total_cost*1.3)
else:
    print("invalid time")
# Out:
# enter the time at which the boat is required for : night
# the amount of travel distance5
# 13.0

# %%
unit=int(input("enter the units of electricity used"))
if unit>200:
  charge=(500+((unit-200)*10))
  print(charge)
elif 200>unit>100:
  charge=((unit-100)*5)
  print(charge)
else:
  print("no charge for consumption under first 100 unit")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-203ef3673397> in <cell line: 1>()
# ----> 1 unit=int(input("enter the units of electricity used"))
#       2 if unit>200:
#       3   charge=(500+((unit-200)*10))
#       4   print(charge)
#       5 elif 200>unit>100:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
#ML beginning
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat
sal=pd.read_csv("https://raw.githubusercontent.com/YBIFoundation/Dataset/f83fe655797d5d59f8c36d3df9fc09bd1fbfe4b4/Salary%20Data.csv")
sal
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
sal.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
sal.shape
# Out:
# (40, 2)

# %%
sal['Experience Years'].mean()
# Out:
# 5.1525

# %%
sal["Experience Years"].min()
# Out:
# 1.1

# %%
y=sal["Salary"]
x=sal[["Experience Years"]]
x.shape
# Out:
# (40, 1)

# %%
#training,testing,spliting
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test=train_test_split(x,y)
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((30, 1), (10, 1), (30,), (10,))

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y,train_size=0.9,random_state=2529)
x_train
# Out:
#     Experience Years
# 19               4.5
# 38              10.3
# 27               6.2
# 14               3.9
# 17               4.1
# 12               3.7
# 1                1.2
# 6                2.5
# 28               6.5
# 31               7.9
# 34               8.7
# 20               4.7
# 4                2.0
# 3                1.5
# 18               4.3
# 26               6.0
# 2                1.3
# 22               5.1
# 35               9.0
# 7                2.9
# 39              10.5
# 30               7.1
# 10               3.2
# 0                1.1
# 9                3.2
# 13               3.8
# 5                2.2
# 37               9.6
# 23               5.3
# 25               5.9
# 21               4.9
# 24               5.5
# 8                3.0
# 36               9.5
# 15               4.0
# 32               8.2

# %%
x_train.shape
# Out:
# (36, 1)

# %%
y_train.shape
# Out:
# (4, 1)

# %%
sal.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
sal.tail()
# Out:
#     Experience Years  Salary
# 35               9.0  105582
# 36               9.5  116969
# 37               9.6  112635
# 38              10.3  122391
# 39              10.5  121872

# %%
import matplotlib.pyplot as plt
plt.plot(sal["Experience Years"],sal["Salary"],color='yellow')
plt.ylabel('SALARY')
plt.xlabel('EXPERIENCE YEARS')
plt.title('EXPERIENCE VS SALARY')
plt.show()

# %%
plt.hist(sal['Experience Years'],bins=20,color='red')
plt.ylabel('SALARY')
plt.xlabel('EXPERIENCE YEARS')
plt.title('EXPERIENCE VS SALARY')
plt.show()

# %%
plt.scatter(x=sal['Experience Years'],y=sal['Salary'],color='red')
plt.ylabel('SALARY')
plt.xlabel('EXPERIENCE YEARS')
plt.title('EXPERIENCE VS SALARY')
plt.show()

# %%
import seaborn as sns
sns.boxplot(x=sal['Salary'])
# Out:
# <Axes: xlabel='Salary'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Assuming 'x' and 'y' are your original feature and target data
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.9, random_state=2529)

# Verify the shapes now
print(x_train.shape)
print(y_train.shape)

model = LinearRegression()
model.fit(x_train, y_train)  # This should now work without errors
# Out:
# (36, 1)
# (36,)
# LinearRegression()

# %%
model.intercept_
# Out:
# 26153.931314830363

# %%
model.coef_
# Out:
# array([9426.56013457])

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 90254.54022989,  59146.89178581, 106279.69245865,  63860.1718531 ])

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.049858109379490215
